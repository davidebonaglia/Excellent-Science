# %%
import pandas as pd

data_dir = '/Users/davidebonaglia/Dropbox/Projects UNU/Excellent Science/'
H2020BiblioData = data_dir + 'H2020BiblioData&Indicators_ExcelScie_ResEuro_ProjIDs_v1.3.1.xlsx'

H2020BiblioData = pd.read_excel(H2020BiblioData)
H2020BiblioData.head(5)
# Out:
#    Digital Object Identifier (DOI)  \
# 0           10.1001/jama.2016.0312
# 1           10.1001/jama.2016.1975
# 2          10.1001/jama.2016.20644
# 3           10.1001/jama.2016.4218
# 4           10.1001/jama.2017.6895
#
#                      Funding Agency and Grant Number  \
# 0                                                  0
# 1  EUNICE KENNEDY SHRIVER NATIONAL INSTITUTE OF C...
# 2  European Union's Innovative Medicines Initiati...
# 3  European Union's Innovative Medicines Initiati...
# 4  European Union/European Federation of Pharmace...
#
#                                Funding Award Numbers  \
# 0                                                  0
# 1  098395|102215|104150|104150/Z/14/Z|323195|G050...
# 2                                             115854
# 3                                             115854
# 4                               115372|115736|116020
#
#                                 Funding Organization  \
# ...

# %%
#xx = list(H2020BiblioData.columns.values)

# %%
#cd_project_01
cd_project_01 = H2020BiblioData[[' Digital Object Identifier (DOI)', 'CD_PROJECT_ID_01', 'programme_PROJ_ID_01', '_mv_CD_ACTION_TYPE_PROJ_ID_01',
                                         'start_date_PROJ_ID_01', 'end_date_PROJ_ID_01', 'CD_PROJECT_FRAC']]

cd_project_01 = cd_project_01.drop_duplicates()

#rename columns
cd_project_01 = cd_project_01.rename(columns={' Digital Object Identifier (DOI)': 'publication',
                                                'CD_PROJECT_ID_01' : 'project_id',
                                                'programme_PROJ_ID_01': 'progr_proj_id',
                                                '_mv_CD_ACTION_TYPE_PROJ_ID_01': 'action_type_proj_id',
                                                'start_date_PROJ_ID_01' : 'starting_date',
                                                'end_date_PROJ_ID_01' : 'ending_date',
                                                'CD_PROJECT_FRAC' : 'fractional_counting'})
                                                

cd_project_01
# Out:
#                         publication  project_id   progr_proj_id  \
# 0            10.1001/jama.2016.0312      655502  ['H2020-MSCA']
# 1            10.1001/jama.2016.1975      633595   ['H2020-SC1']
# 2           10.1001/jama.2016.20644      115854   ['H2020-SC1']
# 3            10.1001/jama.2016.4218      115854   ['H2020-SC1']
# 4            10.1001/jama.2017.6895      116020   ['H2020-SC1']
# ...                             ...         ...             ...
# 123112   10.7900/jot.2017jan19.2147      669240   ['H2020-ERC']
# 123113  10.7900/jot.20181apr19.2188      669240   ['H2020-ERC']
# 123114   10.7900/jot.2018jun13.2222      691246  ['H2020-MSCA']
# 123115   10.7900/jot.2018mar08.2219      669240   ['H2020-ERC']
# 123116   10.7900/jot.2020feb06.2268      844451  ['H2020-MSCA']
#
#        action_type_proj_id starting_date ending_date  fractional_counting
# 0            MSCA-IF-EF-ST    2015-06-01  2017-12-01                  1.0
# ...

# %%
#cd_project_02
cd_project_02 = H2020BiblioData[[' Digital Object Identifier (DOI)', 'CD_PROJECT_ID_02', 'programme_PROJ_ID_02', 'mv_CD_ACTION_TYPE_PROJ_ID_02',
                                         'start_date_PROJ_ID_02', 'end_date_PROJ_ID_02', 'CD_PROJECT_FRAC']]

cd_project_02 = cd_project_02.drop_duplicates()
cd_project_02 = cd_project_02.loc[cd_project_02.CD_PROJECT_ID_02 != 0 ]

#rename columns
cd_project_02 = cd_project_02.rename(columns={' Digital Object Identifier (DOI)': 'publication',
                                                'CD_PROJECT_ID_02' : 'project_id',
                                                'programme_PROJ_ID_02': 'progr_proj_id',
                                                'mv_CD_ACTION_TYPE_PROJ_ID_02': 'action_type_proj_id',
                                                'start_date_PROJ_ID_02' : 'starting_date',
                                                'end_date_PROJ_ID_02' : 'ending_date',
                                                'CD_PROJECT_FRAC' : 'fractional_counting'})

cd_project_02
# Out:
#                               publication  project_id   progr_proj_id  \
# 1                  10.1001/jama.2016.1975      669545   ['H2020-ERC']
# 6                  10.1001/jama.2019.3820      669545   ['H2020-ERC']
# 8                 10.1001/jama.2020.13719      833247   ['H2020-ERC']
# 16      10.1001/jamanetworkopen.2018.0725      758813   ['H2020-ERC']
# 23      10.1001/jamanetworkopen.2019.1868      777394   ['H2020-SC1']
# ...                                   ...         ...             ...
# 123000             10.7566/JPSJ.87.041016      694097   ['H2020-ERC']
# 123024                 10.7717/peerj.2946      691154  ['H2020-MSCA']
# 123048                 10.7717/peerj.5025      748167  ['H2020-MSCA']
# 123068                 10.7717/peerj.7208      773921   ['H2020-SC2']
# 123088                 10.7717/peerj.8984      774234   ['H2020-SC2']
#
#        action_type_proj_id starting_date ending_date  fractional_counting
# ...

# %%
#cd_project_03
cd_project_03 = H2020BiblioData[[' Digital Object Identifier (DOI)', 'CD_PROJECT_ID_03', 'programme_PROJ_ID_03', 'mv_CD_ACTION_TYPE_PROJ_ID_03',
                                         'start_date_PROJ_ID_03', 'end_date_PROJ_ID_03', 'CD_PROJECT_FRAC']]

cd_project_03 = cd_project_03.drop_duplicates()
cd_project_03 = cd_project_03.loc[cd_project_03.CD_PROJECT_ID_03 != 0 ]

#rename columns
cd_project_03 = cd_project_03.rename(columns={' Digital Object Identifier (DOI)': 'publication',
                                                'CD_PROJECT_ID_03' : 'project_id',
                                                'programme_PROJ_ID_03': 'progr_proj_id',
                                                'mv_CD_ACTION_TYPE_PROJ_ID_03': 'action_type_proj_id',
                                                'start_date_PROJ_ID_03' : 'starting_date',
                                                'end_date_PROJ_ID_03' : 'ending_date',
                                                'CD_PROJECT_FRAC' : 'fractional_counting'})

cd_project_03
# Out:
#                    publication  project_id   progr_proj_id  \
# 6       10.1001/jama.2019.3820      733206   ['H2020-SC1']
# 602     10.1002/adfm.201908994      787410   ['H2020-ERC']
# 617     10.1002/adfm.201910259      777714  ['H2020-MSCA']
# 619     10.1002/adfm.201910335      787510   ['H2020-ERC']
# 677     10.1002/adfm.202008032      819417   ['H2020-ERC']
# ...                        ...         ...             ...
# 122498      10.7150/thno.34429      777682  ['H2020-MSCA']
# 122514      10.7150/thno.47406      825159   ['H2020-ERC']
# 122796     10.7554/eLife.49562      759432   ['H2020-ERC']
# 122947     10.7554/eLife.60416      671208   ['H2020-ERC']
# 122962     10.7554/eLife.61710      847422   ['H2020-SC1']
#
#        action_type_proj_id starting_date ending_date  fractional_counting
# 6                      RIA    2017-01-01  2022-06-30             0.333333
# 602                ERC-ADG    2019-01-01  2023-12-31             0.333333
# ...

# %%
#cd_project_04
cd_project_04 = H2020BiblioData[[' Digital Object Identifier (DOI)', 'CD_PROJECT_ID_04', 'programme_PROJ_ID_04', 'mv_CD_ACTION_TYPE_PROJ_ID_04',
                                         'start_date_PROJ_ID_04', 'end_date_PROJ_ID_04', 'CD_PROJECT_FRAC']]

cd_project_04 = cd_project_04.drop_duplicates()
cd_project_04 = cd_project_04.loc[cd_project_04.CD_PROJECT_ID_04 != 0 ]

#rename columns
cd_project_04 = cd_project_04.rename(columns={' Digital Object Identifier (DOI)': 'publication',
                                                'CD_PROJECT_ID_04' : 'project_id',
                                                'programme_PROJ_ID_04': 'progr_proj_id',
                                                'mv_CD_ACTION_TYPE_PROJ_ID_04': 'action_type_proj_id',
                                                'start_date_PROJ_ID_04' : 'starting_date',
                                                'end_date_PROJ_ID_04' : 'ending_date',
                                                'CD_PROJECT_FRAC' : 'fractional_counting'})

cd_project_04
# Out:
#                        publication  project_id   progr_proj_id  \
# 619         10.1002/adfm.201910335      819242   ['H2020-ERC']
# 1728        10.1002/anie.201607084      661799  ['H2020-MSCA']
# 10428    10.1007/s00204-018-2354-1      777365   ['H2020-SC1']
# 12453   10.1007/s10654-019-00502-9      757919   ['H2020-ERC']
# 12586    10.1007/s10686-018-9598-x      740963   ['H2020-ERC']
# ...                            ...         ...             ...
# 120022    10.3847/2041-8213/aa91c9      725161   ['H2020-ERC']
# 120090    10.3847/2041-8213/aaf16a      726384   ['H2020-ERC']
# 121460     10.5194/bg-17-3439-2020      821003   ['H2020-SC5']
# 121582   10.5194/essd-11-1783-2019      776810   ['H2020-SC5']
# 121600   10.5194/essd-12-3269-2020      821003   ['H2020-SC5']
#
#        action_type_proj_id starting_date ending_date  fractional_counting
# 619                ERC-COG    2019-11-01  2024-10-31                 0.25
# ...

# %%
#cd_project_05
cd_project_05 = H2020BiblioData[[' Digital Object Identifier (DOI)', 'CD_PROJECT_ID_05', 'programme_PROJ_ID_05', 'mv_CD_ACTION_TYPE_PROJ_ID_05',
                                         'start_date_PROJ_ID_05', 'end_date_PROJ_ID_05', 'CD_PROJECT_FRAC']]

cd_project_05 = cd_project_05.drop_duplicates()
cd_project_05 = cd_project_05.loc[cd_project_05.CD_PROJECT_ID_05 != 0 ]

#rename columns
cd_project_05 = cd_project_05.rename(columns={' Digital Object Identifier (DOI)': 'publication',
                                                'CD_PROJECT_ID_05' : 'project_id',
                                                'programme_PROJ_ID_05': 'progr_proj_id',
                                                'mv_CD_ACTION_TYPE_PROJ_ID_05': 'action_type_proj_id',
                                                'start_date_PROJ_ID_05' : 'starting_date',
                                                'end_date_PROJ_ID_05' : 'ending_date',
                                                'CD_PROJECT_FRAC' : 'fractional_counting'})

cd_project_05
# Out:
#                                publication  project_id    progr_proj_id  \
# 12586            10.1007/s10686-018-9598-x      758892    ['H2020-ERC']
# 17240   10.1016/j.biomaterials.2020.120580      861190   ['H2020-MSCA']
# 18757           10.1016/j.cels.2018.06.002      757850    ['H2020-ERC']
# 41367          10.1021/acs.jpclett.9b03574      823717  ['H2020-INFRA']
# 42177         10.1021/acs.nanolett.9b03837      793159   ['H2020-MSCA']
# 43796              10.1021/acsnano.9b06848      823717  ['H2020-INFRA']
# 47320           10.1038/s41417-020-00224-1      872860   ['H2020-MSCA']
# 48095           10.1038/s41467-018-08063-3      804110    ['H2020-ERC']
# 51597           10.1038/s41597-020-00637-5      824143  ['H2020-INFRA']
# 53715            10.1038/s42005-019-0150-8      793159   ['H2020-MSCA']
# 58332          10.1051/0004-6361/201834878      797794   ['H2020-MSCA']
# 74548                 10.1093/nar/gkaa1028      848158    ['H2020-SC1']
# ...

# %%
#cd_project_06
cd_project_06 = H2020BiblioData[[' Digital Object Identifier (DOI)', 'CD_PROJECT_ID_06', 'programme_PROJ_ID_06', 'mv_CD_ACTION_TYPE_PROJ_ID_06',
                                         'start_date_PROJ_ID_06', 'end_date_PROJ_ID_06', 'CD_PROJECT_FRAC']]

cd_project_06 = cd_project_06.drop_duplicates()
cd_project_06 = cd_project_06.loc[cd_project_06.CD_PROJECT_ID_06 != 0 ]

#rename columns
cd_project_06 = cd_project_06.rename(columns={' Digital Object Identifier (DOI)': 'publication',
                                                'CD_PROJECT_ID_06' : 'project_id',
                                                'programme_PROJ_ID_06': 'progr_proj_id',
                                                'mv_CD_ACTION_TYPE_PROJ_ID_06': 'action_type_proj_id',
                                                'start_date_PROJ_ID_06' : 'starting_date',
                                                'end_date_PROJ_ID_06' : 'ending_date',
                                                'CD_PROJECT_FRAC' : 'fractional_counting'})

cd_project_06
# Out:
#                                publication  project_id   progr_proj_id  \
# 17240   10.1016/j.biomaterials.2020.120580      872860  ['H2020-MSCA']
# 102297           10.1186/s13073-020-0713-z      785907   ['H2020-FET']
# 109698            10.3389/fchem.2020.00496      859908  ['H2020-MSCA']
# 116010           10.3390/molecules25051181      859908  ['H2020-MSCA']
# 116026           10.3390/molecules25092219      859908  ['H2020-MSCA']
# 116096           10.3390/molecules26113272      860173  ['H2020-MSCA']
# 116533       10.3390/pharmaceutics12111022      872860  ['H2020-MSCA']
# 116729               10.3390/polym13060907      861190  ['H2020-MSCA']
#
#        action_type_proj_id starting_date ending_date  fractional_counting
# 17240            MSCA-RISE    2020-04-01  2025-03-31             0.166667
# 102297             SGA-RIA    2018-04-01  2020-03-31             0.142857
# 109698        MSCA-ITN-ETN    2020-02-01  2024-01-31             0.111111
# ...

# %%
#cd_project_07
cd_project_07 = H2020BiblioData[[' Digital Object Identifier (DOI)', 'CD_PROJECT_ID_07', 'programme_PROJ_ID_07', 'mv_CD_ACTION_TYPE_PROJ_ID_07',
                                         'start_date_PROJ_ID_07', 'end_date_PROJ_ID_07', 'CD_PROJECT_FRAC']]

cd_project_07 = cd_project_07.drop_duplicates()
cd_project_07 = cd_project_07.loc[cd_project_07.CD_PROJECT_ID_07 != 0 ]

#rename columns
cd_project_07 = cd_project_07.rename(columns={' Digital Object Identifier (DOI)': 'publication',
                                                'CD_PROJECT_ID_07' : 'project_id',
                                                'programme_PROJ_ID_07': 'progr_proj_id',
                                                'mv_CD_ACTION_TYPE_PROJ_ID_07': 'action_type_proj_id',
                                                'start_date_PROJ_ID_07' : 'starting_date',
                                                'end_date_PROJ_ID_07' : 'ending_date',
                                                'CD_PROJECT_FRAC' : 'fractional_counting'})

cd_project_07
# Out:
#                       publication  project_id   progr_proj_id  \
# 102297  10.1186/s13073-020-0713-z      825812   ['H2020-SC1']
# 109698   10.3389/fchem.2020.00496      860173  ['H2020-MSCA']
# 116010  10.3390/molecules25051181      860173  ['H2020-MSCA']
# 116026  10.3390/molecules25092219      860173  ['H2020-MSCA']
# 116096  10.3390/molecules26113272      861190  ['H2020-MSCA']
# 116729      10.3390/polym13060907      872860  ['H2020-MSCA']
#
#        action_type_proj_id starting_date ending_date  fractional_counting
# 102297                 CSA    2018-11-01  2023-04-30             0.142857
# 109698        MSCA-ITN-EID    2020-03-01  2024-04-30             0.111111
# 116010        MSCA-ITN-EID    2020-03-01  2024-04-30             0.111111
# 116026        MSCA-ITN-EID    2020-03-01  2024-04-30             0.111111
# 116096        MSCA-ITN-ETN    2019-10-01  2024-03-31             0.100000
# 116729           MSCA-RISE    2020-04-01  2025-03-31             0.142857

# %%
import numpy as np

#cd_project_08
#start_date_PROJ_ID_08 and end_date_PROJ_ID_08 are wrong. I added NaN values instead
cd_project_08 = H2020BiblioData[[' Digital Object Identifier (DOI)', 'CD_PROJECT_ID_08', 'programme_PROJ_ID_08', 'mv_CD_ACTION_TYPE_PROJ_ID_08',
                                    'CD_PROJECT_FRAC']]

cd_project_08 = cd_project_08.drop_duplicates()
cd_project_08 = cd_project_08.loc[cd_project_08.CD_PROJECT_ID_08 != 0 ]

#rename columns
cd_project_08 = cd_project_08.rename(columns={' Digital Object Identifier (DOI)': 'publication',
                                                'CD_PROJECT_ID_08' : 'project_id',
                                                'programme_PROJ_ID_08': 'progr_proj_id',
                                                'mv_CD_ACTION_TYPE_PROJ_ID_08': 'action_type_proj_id',
                                                'CD_PROJECT_FRAC' : 'fractional_counting'})

cd_project_08['starting_date'] = np.nan
cd_project_08['ending_date'] = np.nan

#rearrange columns 
cd_project_08 = cd_project_08[['publication', 'project_id', 'progr_proj_id', 'action_type_proj_id',
                                'starting_date', 'ending_date', 'fractional_counting']]

cd_project_08
# Out:
#                       publication  project_id   progr_proj_id  \
# 109698   10.3389/fchem.2020.00496      861190  ['H2020-MSCA']
# 116010  10.3390/molecules25051181      861190  ['H2020-MSCA']
# 116026  10.3390/molecules25092219      861190  ['H2020-MSCA']
# 116096  10.3390/molecules26113272      872391  ['H2020-MSCA']
#
#        action_type_proj_id  starting_date  ending_date  fractional_counting
# 109698        MSCA-ITN-ETN            NaN          NaN             0.111111
# 116010        MSCA-ITN-ETN            NaN          NaN             0.111111
# 116026        MSCA-ITN-ETN            NaN          NaN             0.111111
# 116096           MSCA-RISE            NaN          NaN             0.100000

# %%
#cd_project_09
cd_project_09 = H2020BiblioData[[' Digital Object Identifier (DOI)', 'CD_PROJECT_ID_09', 'programme_PROJ_ID_09', 'mv_CD_ACTION_TYPE_PROJ_ID_09',
                                         'start_date_PROJ_ID_09', 'end_date_PROJ_ID_09', 'CD_PROJECT_FRAC']]

cd_project_09 = cd_project_09.drop_duplicates()
cd_project_09 = cd_project_09.loc[cd_project_09.CD_PROJECT_ID_09 != 0 ]

#rename columns
cd_project_09 = cd_project_09.rename(columns={' Digital Object Identifier (DOI)': 'publication',
                                                'CD_PROJECT_ID_09' : 'project_id',
                                                'programme_PROJ_ID_09': 'progr_proj_id',
                                                'mv_CD_ACTION_TYPE_PROJ_ID_09': 'action_type_proj_id',
                                                'start_date_PROJ_ID_09' : 'starting_date',
                                                'end_date_PROJ_ID_09' : 'ending_date',
                                                'CD_PROJECT_FRAC' : 'fractional_counting'})

cd_project_09
# Out:
#                       publication  project_id   progr_proj_id  \
# 109698   10.3389/fchem.2020.00496      872860  ['H2020-MSCA']
# 116010  10.3390/molecules25051181      872860  ['H2020-MSCA']
# 116026  10.3390/molecules25092219      872860  ['H2020-MSCA']
# 116096  10.3390/molecules26113272      872860  ['H2020-MSCA']
#
#        action_type_proj_id starting_date ending_date  fractional_counting
# 109698           MSCA-RISE    2020-04-01  2025-03-31             0.111111
# 116010           MSCA-RISE    2020-04-01  2025-03-31             0.111111
# 116026           MSCA-RISE    2020-04-01  2025-03-31             0.111111
# 116096           MSCA-RISE    2020-04-01  2025-03-31             0.100000

# %%
#cd_project_10
cd_project_10 = H2020BiblioData[[' Digital Object Identifier (DOI)', 'CD_PROJECT_ID_10', 'programme_PROJ_ID_10', 'mv_CD_ACTION_TYPE_PROJ_ID_10',
                                         'start_date_PROJ_ID_10', 'end_date_PROJ_ID_10', 'CD_PROJECT_FRAC']]

cd_project_10 = cd_project_10.drop_duplicates()
cd_project_10 = cd_project_10.loc[cd_project_10.CD_PROJECT_ID_10 != 0 ]

#rename columns
cd_project_10 = cd_project_10.rename(columns={' Digital Object Identifier (DOI)': 'publication',
                                                'CD_PROJECT_ID_10' : 'project_id',
                                                'programme_PROJ_ID_10': 'progr_proj_id',
                                                'mv_CD_ACTION_TYPE_PROJ_ID_10': 'action_type_proj_id',
                                                'start_date_PROJ_ID_10' : 'starting_date',
                                                'end_date_PROJ_ID_10' : 'ending_date',
                                                'CD_PROJECT_FRAC' : 'fractional_counting'})

cd_project_10
# Out:
#                       publication  project_id   progr_proj_id  \
# 116096  10.3390/molecules26113272      952520  ['H2020-SEWP']
#
#        action_type_proj_id starting_date ending_date  fractional_counting
# 116096                 CSA    2020-09-01  2023-08-31                  0.1

# %%
#final database
data = cd_project_01.append(cd_project_02)
data = data.append(cd_project_03)
data = data.append(cd_project_04)
data = data.append(cd_project_05)
data = data.append(cd_project_06)
data = data.append(cd_project_07)
data = data.append(cd_project_08)
data = data.append(cd_project_09)
data = data.append(cd_project_10)

data = data.sort_values(by=['publication'], ascending = True)

data['starting_date'] =  pd.to_datetime(data['starting_date'], format='%Y-%m-%d')
data['starting_date'] = data['starting_date'].dt.strftime('%Y-%m-%d')

data['ending_date'] =  pd.to_datetime(data['ending_date'], format='%Y-%m-%d')
data['ending_date'] = data['ending_date'].dt.strftime('%Y-%m-%d')
# Out:
# <ipython-input-13-5a68a0a6ac87>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = cd_project_01.append(cd_project_02)
# <ipython-input-13-5a68a0a6ac87>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(cd_project_03)
# <ipython-input-13-5a68a0a6ac87>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(cd_project_04)
# <ipython-input-13-5a68a0a6ac87>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(cd_project_05)
# ...

# %%
data
# Out:
#                         publication  project_id   progr_proj_id  \
# 0            10.1001/jama.2016.0312      655502  ['H2020-MSCA']
# 1            10.1001/jama.2016.1975      669545   ['H2020-ERC']
# 1            10.1001/jama.2016.1975      633595   ['H2020-SC1']
# 2           10.1001/jama.2016.20644      115854   ['H2020-SC1']
# 3            10.1001/jama.2016.4218      115854   ['H2020-SC1']
# ...                             ...         ...             ...
# 123112   10.7900/jot.2017jan19.2147      669240   ['H2020-ERC']
# 123113  10.7900/jot.20181apr19.2188      669240   ['H2020-ERC']
# 123114   10.7900/jot.2018jun13.2222      691246  ['H2020-MSCA']
# 123115   10.7900/jot.2018mar08.2219      669240   ['H2020-ERC']
# 123116   10.7900/jot.2020feb06.2268      844451  ['H2020-MSCA']
#
#        action_type_proj_id starting_date ending_date  fractional_counting
# 0            MSCA-IF-EF-ST    2015-06-01  2017-12-01                  1.0
# ...

# %%
##############################################################
#progr_proj_id

# %%
#select just project_id and progr_proj_id
progr_proj_id = data[['project_id', 'progr_proj_id']]
progr_proj_id = progr_proj_id.sort_values(by=['project_id'], ascending=True)
progr_proj_id = progr_proj_id.drop_duplicates()

#clean progr_proj_id from H2020 and remove non-alphanumeric chars 
progr_proj_id['progr_proj_id'] = progr_proj_id['progr_proj_id'].str.replace('H2020', '')
progr_proj_id['progr_proj_id'] = progr_proj_id['progr_proj_id'].str.replace('\W', ' ')

#strip the string on the left and on the right (remove spaces in the beginning and the end of the string)
progr_proj_id['progr_proj_id'] = progr_proj_id['progr_proj_id'].str.lstrip() 
progr_proj_id['progr_proj_id'] = progr_proj_id['progr_proj_id'].str.rstrip()
# Out:
# <ipython-input-16-53f04e230ae8>:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   progr_proj_id['progr_proj_id'] = progr_proj_id['progr_proj_id'].str.replace('\W', ' ')

# %%
progr_proj_id
# Out:
#         project_id progr_proj_id
# 75209       115797           SC1
# 64605       115842           SC1
# 94699       115843           SC1
# 101599      115847           SC1
# 46189       115848           SC1
# ...            ...           ...
# 86429    101017171     LEITs ICT
# 82889    101017226     LEITs ICT
# 2468     101023615          MSCA
# 17567    101025785          MSCA
# 59568    101026196          MSCA
#
# [13543 rows x 2 columns]

# %%
i = progr_proj_id.columns.get_loc('progr_proj_id')
xx = progr_proj_id['progr_proj_id'].str.split(" ", expand=True)
xx2 = pd.concat([progr_proj_id.iloc[:, :i], xx, progr_proj_id.iloc[:, i+1:]], axis=1)
xx2 = xx2.rename(columns={0: 'progr_proj_id_1', 1: 'progr_proj_id_2'})
xx2 = xx2[['project_id', 'progr_proj_id_1', 'progr_proj_id_2']]
xx2
# Out:
#         project_id progr_proj_id_1 progr_proj_id_2
# 75209       115797             SC1            None
# 64605       115842             SC1            None
# 94699       115843             SC1            None
# 101599      115847             SC1            None
# 46189       115848             SC1            None
# ...            ...             ...             ...
# 86429    101017171           LEITs             ICT
# 82889    101017226           LEITs             ICT
# 2468     101023615            MSCA            None
# 17567    101025785            MSCA            None
# 59568    101026196            MSCA            None
#
# [13543 rows x 3 columns]

# %%
#restructure the dataframe so that each project has a row for each project_id
progr_proj_id_1 = xx2[['project_id', 'progr_proj_id_1']]
progr_proj_id_1 = progr_proj_id_1.rename(columns={'progr_proj_id_1': 'progr_proj_id'})
progr_proj_id_2 = xx2[['project_id', 'progr_proj_id_2']]
progr_proj_id_2 = progr_proj_id_2.rename(columns={'progr_proj_id_2': 'progr_proj_id'})

xx3 = progr_proj_id_1.append(progr_proj_id_2)
xx3 = xx3.drop_duplicates()
xx3 = xx3.sort_values(by=['project_id'], ascending=True)
xx3 = xx3.dropna()

#clean progr_proj_id
xx3 = xx3.loc[(xx3.progr_proj_id != 'Manufacturing') & 
                (xx3.progr_proj_id != 'Space') &
                (xx3.progr_proj_id != 'Materials') &
                (xx3.progr_proj_id != 'Biotech') &
                (xx3.progr_proj_id != 'in') &
                (xx3.progr_proj_id != 'Nano') &
                (xx3.progr_proj_id != 'Innvoation') &
                (xx3.progr_proj_id !=  '0')]

xx3
# Out:
# <ipython-input-19-d5084201f5f7>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   xx3 = progr_proj_id_1.append(progr_proj_id_2)
#         project_id progr_proj_id
# 75209       115797           SC1
# 64605       115842           SC1
# 94699       115843           SC1
# 101599      115847           SC1
# 46189       115848           SC1
# ...            ...           ...
# 82889    101017226           ICT
# 82889    101017226         LEITs
# 2468     101023615          MSCA
# 17567    101025785          MSCA
# 59568    101026196          MSCA
#
# [14275 rows x 2 columns]

# %%
#get dummies for progr_proj_id
dummies_progr_proj_id = pd.get_dummies(xx3, columns=['progr_proj_id'])
dummies_progr_proj_id = dummies_progr_proj_id.groupby(['project_id']).max().reset_index()
dummies_progr_proj_id = dummies_progr_proj_id.sort_values(by=['project_id'], ascending=True)
dummies_progr_proj_id
# Out:
#        project_id  progr_proj_id_ERC  progr_proj_id_FET  progr_proj_id_FTI  \
# 0          115797                  0                  0                  0
# 1          115842                  0                  0                  0
# 2          115843                  0                  0                  0
# 3          115847                  0                  0                  0
# 4          115848                  0                  0                  0
# ...           ...                ...                ...                ...
# 13456   101017171                  0                  0                  0
# 13457   101017226                  0                  0                  0
# 13458   101023615                  0                  0                  0
# 13459   101025785                  0                  0                  0
# 13460   101026196                  0                  0                  0
#
# ...

# %%
#save file dummies_progr_proj_id 
data_dir = '/Users/davidebonaglia/Dropbox/Projects UNU/Excellent Science/data_cleaned/'
dummies_progr_proj_id.to_excel(data_dir + 'dummies_progr_proj_id.xlsx', index=False)

# %%
############################################################################

# %%
#select just project_id and progr_proj_id
action_type_proj_id = data[['project_id', 'action_type_proj_id']]
action_type_proj_id = action_type_proj_id.sort_values(by=['project_id'], ascending=True)
action_type_proj_id = action_type_proj_id.drop_duplicates()
action_type_proj_id
# Out:
#         project_id action_type_proj_id
# 75209       115797        JTI-IMI2-RIA
# 64605       115842        JTI-IMI2-RIA
# 94699       115843        JTI-IMI2-RIA
# 101599      115847        JTI-IMI2-RIA
# 46189       115848        JTI-IMI2-RIA
# ...            ...                 ...
# 86429    101017171                 RIA
# 82889    101017226                 RIA
# 2468     101023615       MSCA-IF-EF-ST
# 17567    101025785       MSCA-IF-EF-ST
# 59568    101026196       MSCA-IF-EF-ST
#
# [13543 rows x 2 columns]

# %%
i = action_type_proj_id.columns.get_loc('action_type_proj_id')
xx = action_type_proj_id['action_type_proj_id'].str.split("-", expand=True)
xx2 = pd.concat([action_type_proj_id.iloc[:, :i], xx], axis=1)
xx2 = xx2.rename(columns={0: 'action_type_proj_id_1', 1: 'action_type_proj_id_2', 2: 'action_type_proj_id_3', 3: 'action_type_proj_id_4'})
#xx2 = xx2[['project_id', 'progr_proj_id_1', 'progr_proj_id_2']]
xx2
# Out:
#         project_id action_type_proj_id_1 action_type_proj_id_2  \
# 75209       115797                   JTI                  IMI2
# 64605       115842                   JTI                  IMI2
# 94699       115843                   JTI                  IMI2
# 101599      115847                   JTI                  IMI2
# 46189       115848                   JTI                  IMI2
# ...            ...                   ...                   ...
# 86429    101017171                   RIA                  None
# 82889    101017226                   RIA                  None
# 2468     101023615                  MSCA                    IF
# 17567    101025785                  MSCA                    IF
# 59568    101026196                  MSCA                    IF
#
#        action_type_proj_id_3 action_type_proj_id_4
# 75209                    RIA                  None
# 64605                    RIA                  None
# 94699                    RIA                  None
# ...

# %%
#restructure the dataframe so that each project has a row for each project_id
action_type_proj_id_1 = xx2[['project_id', 'action_type_proj_id_1']]
action_type_proj_id_1 = action_type_proj_id_1.rename(columns={'action_type_proj_id_1': 'action_type_proj_id'})

action_type_proj_id_2 = xx2[['project_id', 'action_type_proj_id_2']]
action_type_proj_id_2 = action_type_proj_id_2.rename(columns={'action_type_proj_id_2': 'action_type_proj_id'})

action_type_proj_iD_3 = xx2[['project_id', 'action_type_proj_id_3']]
action_type_proj_iD_3 = action_type_proj_iD_3.rename(columns={'action_type_proj_id_3': 'action_type_proj_id'})

action_type_proj_id_4 = xx2[['project_id', 'action_type_proj_id_4']]
action_type_proj_id_4 = action_type_proj_id_4.rename(columns={'action_type_proj_id_4': 'action_type_proj_id'})

xx3 = action_type_proj_id_1.append(action_type_proj_id_2)
xx3 = xx3.append(action_type_proj_iD_3)
xx3 = xx3.append(action_type_proj_id_4)

xx3 = xx3.drop_duplicates()
xx3 = xx3.sort_values(by=['project_id'], ascending=True)
xx3 = xx3.dropna()

#clean action_type_proj_id
xx3 = xx3.loc[(xx3.action_type_proj_id != '2') & 
                (xx3.action_type_proj_id != '2b')]

xx3
# Out:
# <ipython-input-25-997fecebe3ba>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   xx3 = action_type_proj_id_1.append(action_type_proj_id_2)
# <ipython-input-25-997fecebe3ba>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   xx3 = xx3.append(action_type_proj_iD_3)
# <ipython-input-25-997fecebe3ba>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   xx3 = xx3.append(action_type_proj_id_4)
#        project_id action_type_proj_id
# 75209      115797                 JTI
# 75209      115797                IMI2
# 75209      115797                 RIA
# 64605      115842                IMI2
# 64605      115842                 RIA
# ...           ...                 ...
# 17567   101025785                  ST
# ...

# %%
#get dummies for action_type_proj_id
dummies_action_type_proj_id = pd.get_dummies(xx3, columns=['action_type_proj_id'])
dummies_action_type_proj_id = dummies_action_type_proj_id.groupby(['project_id']).max().reset_index()
dummies_action_type_proj_id = dummies_action_type_proj_id.sort_values(by=['project_id'], ascending=True)
dummies_action_type_proj_id
# Out:
#        project_id  action_type_proj_id_ADG  action_type_proj_id_BBI  \
# 0          115797                        0                        0
# 1          115842                        0                        0
# 2          115843                        0                        0
# 3          115847                        0                        0
# 4          115848                        0                        0
# ...           ...                      ...                      ...
# 13538   101017171                        0                        0
# 13539   101017226                        0                        0
# 13540   101023615                        0                        0
# 13541   101025785                        0                        0
# 13542   101026196                        0                        0
#
#        action_type_proj_id_CAR  action_type_proj_id_COFUND  \
# 0                            0                           0
# ...

# %%
#save
data_dir = '/Users/davidebonaglia/Dropbox/Projects UNU/Excellent Science/data_cleaned/'
dummies_action_type_proj_id.to_excel(data_dir + 'dummies_action_type_proj_id.xlsx', index=False)

# %%
################################################

# %%
import numpy as np

fractional_counting_data = pd.merge(data, dummies_progr_proj_id, how='left', on='project_id')
fractional_counting_data = pd.merge(fractional_counting_data, dummies_action_type_proj_id, how='left', on='project_id')

fractional_counting_data = fractional_counting_data.fillna(0)

fractional_counting_data['progr_proj_id_ERC'] = fractional_counting_data['progr_proj_id_ERC'].astype(int)
fractional_counting_data['progr_proj_id_FET'] = fractional_counting_data['progr_proj_id_FET'].astype(int)
fractional_counting_data['progr_proj_id_FTI'] = fractional_counting_data['progr_proj_id_FTI'].astype(int)
fractional_counting_data['progr_proj_id_ICT'] = fractional_counting_data['progr_proj_id_ICT'].astype(int)
fractional_counting_data['progr_proj_id_INFRA'] = fractional_counting_data['progr_proj_id_INFRA'].astype(int)
fractional_counting_data['progr_proj_id_LEITs'] = fractional_counting_data['progr_proj_id_LEITs'].astype(int)
fractional_counting_data['progr_proj_id_MSCA'] = fractional_counting_data['progr_proj_id_MSCA'].astype(int)
fractional_counting_data['progr_proj_id_SC1'] = fractional_counting_data['progr_proj_id_SC1'].astype(int)
fractional_counting_data['progr_proj_id_SC2'] = fractional_counting_data['progr_proj_id_SC2'].astype(int)
fractional_counting_data['progr_proj_id_SC3'] = fractional_counting_data['progr_proj_id_SC3'].astype(int)
fractional_counting_data['progr_proj_id_SC4'] = fractional_counting_data['progr_proj_id_SC4'].astype(int)
fractional_counting_data['progr_proj_id_SC5'] = fractional_counting_data['progr_proj_id_SC5'].astype(int)
fractional_counting_data['progr_proj_id_SC6'] = fractional_counting_data['progr_proj_id_SC6'].astype(int)
fractional_counting_data['progr_proj_id_SC7'] = fractional_counting_data['progr_proj_id_SC7'].astype(int)
fractional_counting_data['progr_proj_id_SEWP'] = fractional_counting_data['progr_proj_id_SEWP'].astype(int)
fractional_counting_data['progr_proj_id_SWAFS'] = fractional_counting_data['progr_proj_id_SWAFS'].astype(int)

fractional_counting_data = fractional_counting_data.sort_values(by=['publication', 'project_id', 'starting_date'], ascending=True)

fractional_counting_data
# Out:
#                         publication  project_id   progr_proj_id  \
# 0            10.1001/jama.2016.0312      655502  ['H2020-MSCA']
# 2            10.1001/jama.2016.1975      633595   ['H2020-SC1']
# 1            10.1001/jama.2016.1975      669545   ['H2020-ERC']
# 3           10.1001/jama.2016.20644      115854   ['H2020-SC1']
# 4            10.1001/jama.2016.4218      115854   ['H2020-SC1']
# ...                             ...         ...             ...
# 132016   10.7900/jot.2017jan19.2147      669240   ['H2020-ERC']
# 132017  10.7900/jot.20181apr19.2188      669240   ['H2020-ERC']
# 132018   10.7900/jot.2018jun13.2222      691246  ['H2020-MSCA']
# 132019   10.7900/jot.2018mar08.2219      669240   ['H2020-ERC']
# 132020   10.7900/jot.2020feb06.2268      844451  ['H2020-MSCA']
#
#        action_type_proj_id starting_date ending_date  fractional_counting  \
# 0            MSCA-IF-EF-ST    2015-06-01  2017-12-01                  1.0
# ...

# %%
#save
data_dir = '/Users/davidebonaglia/Dropbox/Projects UNU/Excellent Science/data_cleaned/'
fractional_counting_data.to_excel(data_dir + 'fractional_counting_data.xlsx', index=False)
